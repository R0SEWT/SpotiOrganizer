# %% [markdown]
# # SpotiOrganizer

# %% [markdown]
# Este proyecto busca resolver el problema que representa el tener muchas canciones en likes, agrupándolas en playlists utilizando algoritmos de clustering como K-means.
#
# Para ello, se analiza el genero de la cancion y otros metadatos asociados a las caracteristicas del audio.

# %% [markdown]
# ## Obtencion de la lista de "Me Gustas" del usuario
#
# ### Conectarse con Spotipy
#
# Para acceder a esta informacion se requiere generar unas credenciales en "Spotify Developer Dashboard", se debe configurar el `.env` para poder autenticarse correctamente (El URL de redireccion no necesariamente debe ser valido, pero si identico).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
from dotenv import load_dotenv
import os
import spotipy
from spotipy.oauth2 import SpotifyOAuth


load_dotenv(".env")

scope = 'user-library-read,playlist-modify-public,playlist-modify-private'

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=os.getenv('SPOTIPY_CLIENT_ID'),
    client_secret=os.getenv('SPOTIPY_CLIENT_SECRET'),
    redirect_uri=os.getenv('SPOTIPY_REDIRECT_URI'),
    scope=scope
))

# %% [markdown]
# ### Obtener la lista de origen
# En este caso estamos obteniendo la lista de "Me gustas" del usuario, para poder analizarla.

# %%
try:
    results = sp.current_user_saved_tracks()
except Exception as e:
    print(f'Error al obtener las canciones del usuario: {e}')

tracks = results['items']

while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

print(f'Total de canciones: {len(tracks)}')
# Out:
# Total de canciones: 571

# %%
print(tracks[0]['track']['name'])
# Out:
# Santiago De Chile

# %% [markdown]
# ### Enriquecimiento de Datos
#
# Crearemos un dataframe que contendrá la información de la canción, incluyendo el ID, nombre, y artista.
#
# Dado que el género no siempre está disponible, imputaremos el género basado en el primer artista de la canción.
#
# Además, extraeremos las características del audio para un análisis más profundo.

# %%
track_data = []

audio_feature_numerical_keys = [
    'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
    'instrumentalness', 'liveness', 'valence',
]
audio_feature_categorical_keys = ['tempo', 'time_signature', 'key', 'mode']

artist_genre_cache = {} # hash map para disminuir las llamadas a la API

def get_artist_genre(artist_id):
    if artist_id in artist_genre_cache:
        return artist_genre_cache[artist_id]
    
    artist_info = sp.artist(artist_id)
    genres = artist_info.get('genres', [])
    artist_genre_cache[artist_id] = genres
    return genres

def load_artist_genres(load_json):
    artist_genre_cache = {}
    if load_json:
        try:
            with open('artist_genre_cache.json', 'r') as f:
                artist_genre_cache = json.load(f) 
        except Exception as e:
            print(f'Error al cargar el archivo JSON: {e}')
    return artist_genre_cache

def save_artist_genres(artist_genre_cache, save_json=False):
    if save_json:
        try:
            with open('artist_genre_cache.json', 'w') as f:
                json.dump(artist_genre_cache, f)
        except Exception as e:
            print(f'Error al guardar el archivo JSON: {e}')

# procesar por lotes 

max_batch_size = 99
artist_genre_cache = load_artist_genres(load_json = False)

for i in range(0, len(tracks), max_batch_size):
    try:
        batch = tracks[i:min(i + max_batch_size, len(tracks))] # lotes

        track_ids = [item['track']['id'] for item in batch] #
        print(track_ids)
        audio_features = sp.audio_features(track_ids) # consulta de 100

        for j, item in enumerate(batch):
            track = item['track']
            artist_id = track['artists'][0]['id']
            track_id = track['id']

            genres = get_artist_genre(artist_id)
            genre = genres[0] if genres else None

            audio_feature = audio_features[j]

            track_info = {
                'id': track_id,
                'name': track['name'],
                'artist': track['artists'][0]['name'],
                'genre': genre
            }

            for key in audio_feature_numerical_keys:
                track_info[key] = audio_feature.get(key)

            for key in audio_feature_categorical_keys:
                track_info[key] = audio_feature.get(key)

            track_data.append(track_info)
    except Exception as e:
            print(f"Error al procesar [{i} - {min(i + max_batch_size, len(tracks))}] tracks: {e}") # ajustar reintento

save_artist_genres(artist_genre_cache, save_json=True)
df = pd.DataFrame(track_data)
df.head()
# Out:
# ['3D4iziSjHi4jxG8r4pta7z', '19CmuECYssqkPWANF4nLWM', '2LsbizbOeNa4x6qsi2jAMb', '6hBfF54vgIAdtb5kbbvt75', '1qgtSWA2GbpAXfyC51M1ph', '5FAS5CyNd5jXR9wRpRtn3L', '3w3y8KPTfNeOKPiqUTakBh', '49FYlytm3dAAraYgpoJZux', '0JEoezwc786AUMKs2CBQRI', '7fss5WF5vuXRHvMsYRQXQH', '0ct6r3EGTcMLPtrXHDvVjc', '7ACxUo21jtTHzy7ZEV56vU', '7gKqjNMM4ikt7KFTRsgZgL', '7vOmSP2647oNUGGEhWd1cr', '3QaLlAMZDXa2s8eyVoowjw', '18YCZgBpjvd7OiDzlqffj9', '0GDOu0iuMWjSNyq37706Yj', '7MiZjKawmXTsTNePyTfPyL', '08jZu9HOb1jPh4U95n9Iso', '2tBOR5GtsrEUzvuvhHaiVU', '0zpKWgFT6SpxQhGIlJRnFy', '5d0Keu9WXiN1XZsAG88VcF', '5Kw1iXud2UNTfLfpIMDogG', '077xWZZIJMDRl1fLZSnwEB', '2xizRhme7pYeITbH1NLLGt', '1aDeaDooAd79p2sdImGG4a', '0WFryfbNKPXVtVQlz5dZ8H', '10rzSpg3kTFSr5e5tFy60A', '0obx517J85Rq970CuInlDr', '62xokumU0wMqOSsBuefhmB', '7dU9Z24yR9AKuS9cAe2Tj7', '0YUSVg7dncF1TzZ3IFf6Zh', '1v1oIWf2Xgh54kIWuKsDf6', '7HgG6kaNPUltGHFP6aIS4L', '2kLWSmKHhfUBepkIA9oNe5', '03jdl5GTBhKsgB1Yw8mVPh', '7ueP5u2qkdZbIPN2YA6LR0', '2XXP73OwM2WvZ2vcXAIDz3', '1W0OCrMsRP1SLTEdw3JwEz', '1T0kkgPuLxpEnIXV1NXGFf', '5AIwfXYjGkWCs4KeeTk2Rq', '4OWa2dOlmtvMDhFrFL0QA1', '1Sz402s2SN6nPicOA8DPah', '7EZvohNWHJ6W3sDOEeBsoU', '6Wv1yv5O9ZfzCdwEhuk31r', '3MbNnqa8NahIrBdKRW2sX6', '6lSypaQOcC6JtzfwpINLGW', '7yCF65vpc7sUwPjftI0iFb', '4BxzNZpcm1j3JczZzGNe2k', '5fdNHVZHbWB1AaXk4RBGVD', '6FfLg6FFqhCsrFOaHIGkg0', '2flxduIqEbsicdmPyj1WVW', '1hiZqVgSKeVPJAjUKgJZMm', '05ascW5kZSLsGM7sdr9Eot', '0pyT9W877RcYtVdl1ZmlvQ', '4bZEZhCq2kqUxnMacXVl5x', '1ozbWlTQASs311dSO5R6vp', '0kc4G5tEdtmTB0w3gYmb01', '569wwTXGm6Ujk1HeJjH6fj', '0n2lJjskWdFCvLI3ExAGha', '6K4t31amVTZDgR3sKmwUJJ', '3TO7bbrUKrOSPGRTB5MeCz', '2U3rA2iYYrTFEeQg4u9S4b', '08THvDquCuP6yqDo5g5JLe', '1vvNmPOiUuyCbgWmtc6yfm', '6h5PAsRni4IRlxWr6uDPTP', '7mitXLIMCflkhZiD34uEQI', '5MhsZlmKJG6X5kTHkdwC4B', '2Foc5Q5nqNiosCNqttzHof', '7ydVhVEl4cRGEAhxo7X5Ic', '1FCsK0oKWCtDOYRPYSrYgO', '63T7DJ1AFDD6Bn8VzG6JE8', '6ftHPJyEHGqMaml3ZEwPm1', '6b4ioB9n5Hkeu2GdSOWzJJ', '3kNQh1pLaQbZZoh6GDzHGp', '1r2EerxDMVQbXxqsqnjUhy', '26ucR33snMkRD6JExhoD6I', '4ubwzNjqHGaZZ5k06PDx1H', '5XWfwjzFNl2pTB737fx7qr', '3fRIuTih8bzc0vtY9fHhvF', '1nquycJ4zLhrT23rwtH5Wj', '100Tm6z29RfHTdUQ6NIs0s', '75ncCwXqalTnnl6t1ruQRq', '5xxR1xl7tiFlITtxzsuow0', '3Pme6ghMt2iCDy4V2SqWPx', '2Ovxs4W5CIMcOIPLJq89ge', '6I9VzXrHxO9rA9A5euc8Ak', '6naxalmIoLFWR0siv8dnQQ', '6ic8OlLUNEATToEFU3xmaH', '7AqteBGkJ5edFjEfYf8mXf', '68WeKkXsg8jUZ57t3bz6qe', '04aAxqtGp5pv12UXAg4pkq', '0M955bMOoilikPXwKLYpoi', '6Nm8h73ycDG2saCnZV8poF', '3Tg8JctqoeIwZ3Rue8BjaI', '3Te8uLyit6X3ncNW8Fp3K2', '47atuTch0AN7NvP9vp42a5', '69Yia3qCLw6N9U80WhLwLn', '3q9G9SvgdfE1fxlvoDIb20']
# ['4dUES55SAFKZp4ekMlLHWZ', '1Hs1uUl8o2VtDp1DABFq0O', '48vnZJGacXc78tqN9gcNPZ', '41wVwJUWk1urN57CfAajMJ', '3OC3AO2zGgcyM7pAFO47YZ', '14Qcrx6Dfjvcj0H8oV8oUW', '2O1EHaqGqQjAqshMGOBfyB', '6IbnUaczZBT34DhaD6S18F', '1lb3H41lbvAN28N7yqRNL9', '1Kb2DqjHRvOcT5xeWtz3t5', '1yqM5O07lL7R6UAdK5jvrR', '5eujblqQ4RS7WDwyqZuMrf', '6HkGQ1F0ZtPHbnp1GCdLZK', '46RHz0aqfrwRmGMdEgenL4', '4h9wh7iOZ0GGn8QVp4RAOB', '5YqEzk3C5c3UZ1D5fJUlXA', '52Zr0sinhWTCRrQhRRY4EP', '7LrvlNIlAjAHVam2XbfN0N', '7zrmKJCfEHluOWJy8LFnTs', '3qwcu0SWVoSLHvlhV41uia', '2w9wysl19C7xQxQYN0S2p1', '4Vr8wfwNnm1HI4pfuANcd4', '749H5Zv3UejDRqMtE1UEAp', '289zheQgtKtJ3qhK5YlDTU', '7Gjlbz4TEoeBGH43eEd3hs', '5N9eyuZBayG61LAuriCFAr', '70tMZ6zOtPq18HMVPUgTyo', '75cH5pVAqBto7c2yyCy4It', '3MFXvcV1mR0ZS1h7aWx4kv', '4VikOud5ZmdmHH6h7uQeDB', '7qsVi4WfUTu87SoDMDi6wX', '6ytwjgwBRxYTUxYJbbkCtf', '0USZx50eApN045zIIyjePN', '7tySfDFfBiCjraLdoy6In5', '6MiVIH3fQlmz44jGx2DXn4', '5T3CKcSWLdue0NWwvF93fI', '2IvetNzSZMH5gwjInoyr18', '2M9ro2krNb7nr7HSprkEgo', '6pWeJvzpQR1ihiUSJklOzD', '447r2keRxpkINmWYp83MlH', '7MVIfkyzuUmQ716j8U7yGR', '02Wse1w8jxhXo5T7kRXgIe', '20n9GjrKJBmN7nMEb21cxc', '1VNWaY3uNfoeWqb5U8x2QX', '3M214U0mwSm041GsQR3nrO', '6dGqGkYDoRrKh5UiIcTT22', '4YLKHaxYieIw6iMVfIvKm7', '4ZUpTMKPYFTfJqamWFU9Zv', '5IXdkgrT4lb9sKIb8tbOQ3', '1ypwNj8eK2qAMDEs4EiIIX', '3gr1pMLpDJGqErHhhl7dEO', '4BY4V1T0RJK1HmD2Q0ClyK', '5DMrREzztuMUkLMDjMpJNY', '1r9xUipOqoNwggBpENDsvJ', '0tr3v4Xa72pzKRlqb7v4Lu', '7svugfnT2bGt8zZTfVIclr', '7fBJbfwWRSCje16iboEAF7', '5Srks36XWpQoF47EYF7ExI', '0y1QJc3SJVPKJ1OvFmFqe6', '2C6fzRAlaWOhKCOsn5a0Nk', '41rML4de6ySFAEgusyvq3R', '0cc3HERtXGbBijz4EGqIWW', '4LAL36nGagL2EYjnXEz3vV', '3SqdNG4NyJwUNguqrmGtZ1', '3SzuLiXQ0rsRRnt8mMXrNo', '3iOFY423D3690MfhE74F8A', '5px66MtTBtuiCuX4yhqNdr', '6tsl5di0G2WX2vkmCiESeH', '3Azo521e0Tacq8znJWaDQO', '1XVunUrydy4GwHcz9LheFE', '1wLYrmTo3HtsoTzfQnRZUY', '7AVpYzzLEQeMoeSq190Ncy', '4MPwBYidOWnwpKlqQYJEzX', '2wVk026aPEMxofNQvBIr8n', '0QUWDjKdItXClpaDbeaTAf', '5lsQpCUKFaqaBGUAl9rZPR', '2a7UjwEFKZcmwxglvwpBb3', '1ozuMsJLTvFIMvlW7AWq95', '3tUk2PzTp8KCIU4cxstJq1', '5U4l5prXjPGv5fnP8nZ3kK', '0ePp0z6IzzKip3DQVw2S5Z', '0m29Kyrm8caxQ22r1rZ4wn', '35LdDKNMwvKftENaj1WIwF', '4LFrQltHBSWQ187o7oWJcS', '7pJzbW7hZ1yOLUBqRq5ZBt', '0YOwYApHSciCRtZmKTEgEa', '2TEnceAmZQR6bLLo5Fx7q9', '5H8M2ffRKcdqJTc6YTt4c2', '1Bo2c0WwPmzognDcmLFNMe', '6H4x2MIySKNhrXdLkLJvcy', '5wjFUjiT4gKddiTX9urqN2', '43HJPKlwZ5jRrMnMfLcQ2T', '0VQW5MJ1BP3FntQ9IzFBNM', '1FKKvyrgMdJFwf0NdM7P5Q', '2v7exGU90YFXvlxUJ9dFvQ', '7CXXzq7SIdH3I4L8m5P5h2', '5hXCTV8OCsNak8OVry7yzM', '5WWxj79hWjVq0wIBDCIw7T', '5wNZtFOmq64IAq7tKkIv8d']
# ['0IfDzKy3k1t6OlfR1Zbo1B', '689o09PSSPw3BxnZHk2hNC', '0j5u5RCr7LV4weyJdxkgR6', '3NHSz1GyC5IeK1soZSjIIX', '6NFVDhRQpIueOxYuw5vQlz', '6E0QvksY8P840Sg2kzPUoy', '6dugx9WBSS8TDxbKqp9zmj', '0jqK7sGTLsHPkQrrcrGuKD', '5s8onl5Lw5q1AijP5BUm7G', '3hdQekpCI2L2j15XwIG2Bd', '2UpDlIw9aI9gK0GphKQjZ8', '6byvMlUkFmNZIl8aprXRhL', '63Zg2q0NxOIoVu7olYHl9t', '7DVhr2t5x2GLwhU3yFS3p1', '6q6YaZyb5MDaPofi60yeew', '7f1MocyOZrNKWgHKfyRHbo', '4zF2MQued46ZoyOm8YQpyw', '2NK6Gq7j1plxRtAyYKdoKp', '0HDh5QaLfCwi2xyvkei917', '29iIRrSuANyjnwag69PHOJ', '34BMzIFvpIgacpqUvuNpOT', '6zI4eWfBKdujnnLmXTIHqJ', '31wVu1EYhWOFCECXTqLWQ4', '2ltWiec0N2xBIu5Hvi5uM4', '1DxEbt6OSbrkRthk6pjZue', '3RRb7m7zpenaWk4wyqcnm3', '1kAg9rfHsyoYLEi7GxA4nM', '4imCqtH8ZVmovPcozJKIom', '78CVgSm8s9pfpwCqvqzEYB', '1DtrlY4mOFrtuqgMYjXVJL', '0fZgVsd0Bk64cAUOcUnQ0X', '0c4KyvtJPmHd5mnXYE5QnZ', '2kRGvesjW6DsXPfSrhjYVp', '4JkQU5XnvMu7WroV5QEZa6', '270ieNCOt945nOdUQubFI5', '5i9BN55sSR94Lfdes8seDp', '34CKJs7AevJpbrE53OFJwO', '2Lo6jY6P6iiGMOfkx5N5Kt', '008BXU3kzngyZKVSjCyxpE', '0Ao7UyZ0IcKH9WQitKd0EL', '1jCBQphSQvBNDsCKYAxtP5', '0PHtFrmcK2kcUVkjb4auvj', '1B0BQaSRHxhI0AUlItY3LK', '0YFoSD5VhoVrRbrnFERpVM', '1MPWWVtOcbdVQQzv01ajl8', '283NIRno2srDoclKAPmk0F', '6KDSrToeuM3UGiqEB1qNRN', '5DRQ4gbV0G3ZlCoNStk3CS', '15m2Op4d1ZtX0ScPaDNKcd', '4s1LnLQZDVvAmzudHJs2kA', '298w9ctLcj2YLvA17c6azA', '4hTXeWayUVMwoz6v1CviSN', '1kasAbWIuasNPe1wNQ29qZ', '59OZFynwa8dvBXCCGZKxCp', '6wLQT5JQj4Px9BbRn7Ylau', '0ohwsEUcp35gxowpLEx0os', '19vhfSUgVJO2enJ6XidUGO', '1J7Shem8gdOSiB5oHOxwNM', '0dQPkfweyWDzZ20Auq3F14', '76GLflx9QeYC0pjhYyASo7', '6VVBXRsXAuN5UvqKNw7j0l', '7bRA9BXy3nNpTOvABDD6EM', '5UB4pyeyR7d4LLJfVN4Kis', '6MllW0bsv7ZRUPSUlzNrkR', '2rGAIoUicUqQ1hK0YlRShJ', '0DXPqpQC4HWt2RbcBv7ttW', '19TGi5QfX6Xj1GuRvStcQ5', '0cAJMbqcT7PZZ2FtlRZD0D', '2THlf4MhAOjn2OpGCmOyUW', '6tR7jCnOKTWzhIMbDdXgSu', '3B56Mr3QophjrI2hB9R2qc', '0DjSa6czo5ywsf6iCtZW5A', '0p3rxgmQPN5y6QEMzliGZc', '1B2KqBbo71jf5n3lftM6G2', '4kJP8Z888wREJ8bRMWNMuk', '0tnUWBM4TDh9YiOh4XWPfF', '2qOvJOOTDDT4BzuN6gs9uE', '6DWAOntbxkpsgKs9iJDEhW', '4ejxQjTq8KyjfEHt6NbrYc', '3KCh9BNkDmh5NIr36w3ERX', '3N17UG6Afw3DxXRcAmkOw5', '6KL2AJqqZhmGeQHBzHq92X', '3rvpRbeo8H1hwxtuj6REcp', '745kmHSwugfDhult82d47J', '5rGXHIBXrINjQuab5zLLKM', '4Z1p2M8ycX5CGzovCXr1QL', '381KeLD7eIbeSEzQmxRs7x', '4EtriYD2qsXOHLCtN9K4db', '4gRu8e9ohJhZx4i1DByb56', '0SG4xDNll1vn1JgIXBDvda', '0bd6dXLLP9gU9R7ExxtJPi', '3my6Uz9RmXcJB7yEnrth7C', '0eCwAiq4qzQJJgQVaqUaCN', '6oytv9amMEx3pxSw9UmEtv', '0vLJOfGD9un0zK5K4UlTO4', '3Hh2NDo6xmxPZEVQ4E7NOT', '5mnpMkzp3Z2RCCbwIEZCbv', '03y045SZqaC94yfXl1cU4E', '6kenOvzeNY6GxXTWKic1wd']
# ['0Gsw1SddS8flrLquzTLxkH', '0RE4crnT3jRms1xxVlEZx2', '0ZICpziYDXDYmQ38hgJuXE', '4tFYyQurNsy2ST5IfgeKhs', '37l4Qgcn1CuGlXx0jKhLpi', '1XekWoZnWxXD7yZODzIDmo', '4mQhKCxIWCdF8oDFnWZ47c', '3giKdDV3Kf8omC3dAsYhaL', '0ZE9OMXrBODYPdXD9OM47q', '13VEtVCYfLTVsq5STs3SlW', '0EMJ0Vs5E6VchaJuLRKdfq', '2kHMrSmCFjxS76sQnhdxfJ', '54BzdXywkL08S9uxFuqwWQ', '4cdo24WodaLQMdYrMa8KaJ', '7DQfrqIhMwLvoQSdtWknOh', '436ZEAYaedGUIUAfrFa6SH', '6wvZKqzwmBZBBuBmgFi9Rd', '3mR3YUKYS7MWCrjKiUFYop', '675IFHR3rOjk7agtkH7UJP', '4RMRDTEu39u9G4XrrEGiXf', '6TSjtPuHtAlS8AHkOu8AQU', '7qfWb1KWbSssLMhfTsyT3C', '7CHDC5kUFQwIHsK1hhGpol', '7AzlLxHn24DxjgQX73F9fU', '3EqqRfm2hQpui26Tz5yBtd', '6cNSOKvw5hYVrOCrLw8joJ', '1xsYj84j7hUDDnTTerGWlH', '1vgfNhZVIU37PVkLXSuek6', '0uCKawvDKjr0AegelrzSuX', '3xdzopoC8RLPrY8lKs0MSa', '6XxIFsqBxiUct0UK7deoJ0', '6nqdgUTiWt4JbABDurkxMI', '3luzfQAgpTWihtYQN5XBmO', '2ksyzVfU0WJoBpu8otr4pz', '5jW3rF4URMdK7tO2xjS5EI', '3XF5xLJHOQQRbWya6hBp7d', '2NWaWZZLFMcr5P4uI2KvWy', '2KOR0FNI6I9OgSH0w59oCI', '74xJ93SJIeY3yunnJ3lbGm', '2HXixVqzzm9rEUIMAWzshl', '5Kc2wsk09yBPe4RDQMwXF4', '619p8Frf2gdv76xeN7At76', '1K45maA9jDR1kBRpojtPmO', '299X2r8Ei0ecTat3CdmdaA', '78OBZL4Z6QHdwwloWIh0Lt', '4oMyggIzClkOcCTvotFLkP', '080PmEUcM6GjVE13suRCfq', '3VSt7R9LHTomKGP1RhkvuT', '655QAfdhzs2uNgDs7YSxPW', '1xOEQF08gMK0lHuBrHHQww', '777zXDJpBufzttU4AJ2dGO', '6YefwI4679EKTwDzbvCpRd', '1jDMi92a9zNQuPD3uPMkla', '598B9RU1jZhObFSQJhisIa', '1mJDRVCd0L65QSxfut8r3u', '79Ze2WRxpZDoMgi3V6vziD', '0xyhHET6yRf0GQyEH6yexU', '5BvuyYHjA98IxU0nQUGzZr', '7f922j0QjIUJI7v3aAGQiP', '35xmSciP2D7fkPVQVjYdKe', '4qn2ZtHRDmcfgVPnl38N8p', '3y7rAWPbsbUpjbqGFxIAww', '57kYeaTLlVpVQMdflUoxYw', '5WFMNTNftON3cLPLVa7kwi', '63WuQOXohQIxOxIFA2K7bR', '3wmy2N3KGBM9qKRRb2bNLr', '0vbtURX4qv1l7besfwmnD8', '5PeuB1pbYu2YiqJyTcgR1T', '5Us3svqTvNAdnQfEYfoL5g', '1TsrGEUQWMA7t542V7ppuP', '5nFQqOyGBIC4jhddXgYNxW', '5Ujrafg3IAx5DjjBUkndSz', '2GZKHCkIh25MTJHAFT7YoQ', '6xiXTpLR2J7epOmttWW984', '1Fw3koFuC2VWhPneAX2Gz4', '7fVAyNC0cFsCNiGxCgSbwV', '6IMZPYjW7FKdpMJcybAQMW', '4umN41ggyywUcvMbZxhcHR', '2bFi0AdS4Ylh0BeJar5yw1', '7tiu52iT5YeFY7QhOCpmOs', '6Ur2sj2Q8E2Dp4x3erQWN4', '0uRC1one5JBBT6MyxNRcjy', '0tKdc5LRn5omaRRJJQ5wlh', '2NdH1GtFbmcoUQBkvX0zUL', '45PIqvbAcMWK8DC3QkQu5p', '4cX2HECxTnhFTGHJ72RYt1', '1Bddl2xpVtMPwn78K8dHu3', '2Kbr1l42WvrWR0O9BaOIGe', '6nSmBTQCy2yZLj8NjNnqcL', '7gwT3HGL84vF7bgtwL1N88', '5rLi8B8qgk6qThwRnKHW2P', '38SWtyvUlLY7JRztpPB7N0', '13yE6UlhBfDgGZ56xUCnXu', '6rj4baRaVhzNcXk3bu4afW', '31Fhs0pNaSsxYEavOPPN88', '2hS7Bn1HsYlBw4xQ6drw1u', '3BVdbbFSuhVBHsvCgqCSTx', '2lXPDGSJBfF3tvelCmPfUN', '1IV1pNKKPtSeJEA5BPTu1e']
# ['6Zq5MmCCWhZMdcsZVbCsbg', '3Nz3EIAo136Ki1fh7hXcfc', '0HqZX76SFLDz2aW8aiqi7G', '17pOLaBouf2EleJjsHfJSg', '06qEGQMavekDfu9fVsFAMz', '27NovPIUIRrOZoCHxABJwK', '6YUTL4dYpB9xZO5qExPf05', '68EkhVWIeULhHxcbi1QhzK', '3ZOEytgrvLwQaqXreDs2Jx', '3bidbhpOYeV4knp8AIu8Xn', '7e89621JPkKaeDSTQ3avtg', '3E4ZzO4ySupnYypDPXcc3D', '3FNy4yzOhHhFBeA5p4ofoq', '7sLAaxuPpzSBZHJeDdhz2U', '39dJktBetsIgMLjFifrm6p', '2LKOHdMsL0K9KwcPRlJK2v', '6lyKOW0FNW6aAZdKVgoM8m', '2XU0oxnq2qxCpomAAuJY8K', '3DCSgpzzdFwH4fwMcGi7Pr', '1KzO88hc8I7InCz4IM0u3J', '5LgEnbi7P6taZ8UKtHeygA', '5y8xgNEwQx8sQfHSuw15Qf', '0RyfX2mvCmwKBEWXD434tq', '4mkrVjzTjKy1qttNNipfsL', '1sIq6r8UYBG03bBcg9qVfc', '3scW7pt0vlhkCCgCNv5YR9', '75UMtPC77vqKRwfSuYuNPO', '2tTmW7RDtMQtBk7m2rYeSw', '0ROMalDdNg3L2HoZP4qFyJ', '45Cll8v6YLVa10EvCrP11j', '4hceSKjrkDTO0nMKFcb3sj', '3qQsdqO1T3IrsaB87i6PAD', '0dSyp0Ll2nLUqUh1uvxb5i', '5Q6fh8OEhBYepJaORz9lxe', '37adYGaYaAWTGhBaOzX4Fh', '1K2RnVhm3eauKnA8PAcPu1', '7kDD0sZCzLWalmbxLX4xMa', '1VrwBgWyGqro52jYSWS5YY', '3tk0F3IofksZWFhRxSOZjI', '5WUSFdBFiSipPACl0nbDEd', '174LzUiYeKlC5rySXPtRg1', '2Xnwl1eRKRJoLDZ6cRxkE3', '4ysVkD5SJnidvdeyKk97Lp', '5k0btdDbZjHtHanzky847r', '4FjNOWxwlUgf30G9fMggpN', '496O2EfJmGm6LQpWjt9bGj', '7piw04hPQZ1OHZ9Fq9JOXR', '5PZ2cqh9Yem2g6cTSOLllz', '3ECQXmZjCKCHZgsVa0DBzS', '2DuXBSTv5pkG9dc5TWDomK', '39K7E651wrt8PorEspTWb5', '2iOuy9LsnYTQCpaUTGApBe', '7xonDv1Le9tMf7F4ZXTzTT', '0ZIxMgutG4aP7jfPcmRnYu', '6BbHSY7jAjT3hDVmjnRUIe', '5HSpMRUC4m3L3q48to2Kmu', '0Yjb59fAq6ShYYouwweNfB', '0sNwv0cBkQCtvAfjzJZbQ8', '4ElzHGmien7nf70YqQMO2h', '7rJ26a6Z13AUOjCXSe10UZ', '4eoMumgTE1bYZxiRqTN4df', '4zym5kQyHls6e5JZxm6UtO', '14rb1k1597yHftzHw46Abe', '1UHdRkhzIpUDZJJMPDTo3f', '2JXn1MQeFqowxtRxgmefuk', '5lEWyaVTW8ynLaKo0Xc5sK', '4Qn4NJZZhMQVxVROSb0Je1', '4am7X8WNcYhqnToqnFH625', '2l2v3pRAsCs6V86PXDHVMe', '5VzfDf3J3AGem9WIX02Kcz', '5Fronw7eoL0huzCEYSZe80', '2xhkAlJjsSo3AqnwgnFBcx', '7yq4Qj7cqayVTp3FF9CWbm', '2JJuPgsSJJTfVZJkVO5CVp', '23wbyzX57usJHzKosmFM5g', '3vPHCKu5UhbGLe9rs8dBGr', '3GwzOCZQzmuZzOq0Rp6jxN', '1nO2vGrP18kP5ok92k3MOH', '6YBBChCWBs546BtgxTtKqA', '2Gt5oL4aEufZvJy9KjEkxi', '749QVthAEMdMPQdZBLQ98S', '6lKRMylSZMtA7EqPl0pcdI', '2YpeDb67231RjR0MgVLzsG', '02MWAaffLxlfxAUY7c5dvx', '4QXiKcZwVr6MmgBXjsdGdU', '7zUhVz7yMmO1mmbfFI8R5i', '3lSOZb5rruEnFbe9xWELF6', '61YM5SkqqeUjIBL7It56cs', '4bW8Scxf4AMpjhdFbNw3dF', '2bFGGsScXp2Tu10jKMCKO6', '5tf1VVWniHgryyumXyJM7w', '6XGDnUY1YOtIRegDVwKugM', '4uSlIN62vRGSsi8RmWp976', '2dsRqyrSxZb86jSo57cRUz', '3dyQfqPEASyhbdCnIteJQY', '1ihuKaXmGw57QvDYSVyDCW', '4hAYQuavbB0FYhyxBTbVal', '0wZMiRXKitvHFhcSqZriAe', '2rDZhKnPaPG054ExZ6nXUS']
# ['22WO8XRRCDhoCUtcLQtl9C', '2Z4FBa6hAEh7VTHYCqXy7P', '6fKCqK8OB2MVnYCHD9moHj', '1kjs5eR4DMzyB0gm1Z8waV', '6lQ7ubRjFRpxkRtlFnMJRl', '0EYOdF5FCkgOJJla8DI2Md', '2DlHlPMa4M17kufBvI2lEN', '0snQkGI5qnAmohLE7jTsTn', '3hJxG3eSoXeI2XbQ9nBeK2', '3yUcJwYu7fXAfqMj9krY6l', '6LtHYDgYHRCHoKK3snfr2w', '6FuGJB290AQMAHTfjOYVaK', '2lAal4IOk6IQFfRkGaLDA6', '1xtGtCsjab1g10nm6joLdZ', '5JKDc7HClAX7gTibgUjuwu', '5kt0OltAfepJ7QHSOch45K', '6iVVHY41LSbfjeCIcki5LJ', '13plTOJUDmgBrTEd7yzTgq', '16PGd9HZZ4TSiQxtZYLSd9', '3iH29NcCxYgI5shlkZrUoB', '5ls62WNKHUUrdF3r1cv83T', '0jk6J6B9ivegJc7dTg10Mp', '2yDkReUeTjk9AT6oPWV55Q', '36uNbyvWCUwSk3AnpQmu2I', '54RpEEWkM8J06EWS7MmtED', '7qBT9qcbtkLqrfm9LiTNB4', '4pK99WOgqZRQbeiac4Wjyi', '39LJCSHy7nB1akjmhMQ7Y7', '2JPLbjOn0wPCngEot2STUS', '6Ph8QwsRfZunN5e1GGBIqa', '3LGsgpx4TfxhXbr07OFKqs', '3YVIXYX8FVRYiQfcc47gyb', '4skuEIloXWuxxgekKupkEH', '0zTSmiDzVkIPUPjsHcUWpe', '1DIXPcTDzTj8ZMHt3PDt8p', '3gUE9hxZtrrNytY4YHaQG1', '1hEh8Hc9lBAFWUghHBsCel', '1J03Vp93ybKIxfzYI4YJtL', '25GrBh4vRCJpb142tggh2E', '2Oql5y6yNB0XUb8OWbi7pq', '0kqWb82ACdjcObDqDqD0zg', '2vOZZ5frOUXGdlyIqIGnUj', '2cGxRwrMyEAp8dEbuZaVv6', '2ZSh2anXpuTLC6utOkavyb', '59TvbAzNoYyOGF6WntnZge', '4z2EeFUp5Lhai9qhHtA6IF', '1ey2nYPIpS7qGeZE649t8o', '40Tn8Uhu2GHHI64Tw8I7Jt', '0xoao6vtEvZxZ7VCv1qji1', '3PuB6UwBXxbyu4y1AbJIwv', '0ZLakHzHWqUIlkeDa4i8aC', '3FAclTFfvUuQYnEsptbK8w', '2wZOlqZsq00tdAlsmyh4YK', '3ECkz4odYU5HCv36zPYRwQ', '3d0SOLPqIBXkPZYl0CwhD7', '0BGwAKW4u8kWOhWFflZxfl', '2uhTEPAQvGHa69xwEEFEpE', '1XbkYc0szlepSM3Na5EcG5', '3IfUwAUPyHvq5vfRMXK1WO', '6xqJ0XqDM9dVEW1jbm78wB', '1ovFnZv6mUe0LzAbfVqOmh', '47enw9R1hdkfuxeSjoDQ0N', '67BtfxlNbhBmCDR2L2l8qd', '5PXOPTdFcIJIumTvhDVpid', '1Ahb1lGCvsRSlmThubFzsy', '5iwz1NiezX7WWjnCgY5TH4', '4OgwXdylh75fHfwUzJTUqg', '5QVX2tGOF4w19BHtWPNpFu', '6ScI1xf3RszISXvLGmitY3', '3FS2e59gXFXrcg7sN2mL5z', '0cOXDRG1giESc1QVrHpbGE', '3qvoWt50uOnKulCDVNkrWT', '3Wrjm47oTz2sjIgck11l5e', '7GV2Vhko6RZloD7DmGUUFJ', '5f8T1Lbd35nauMBA3JfpJj', '4bO6qABw4zTcA9mp37Q5uI']
#                        id                    name            artist  \
# 0  3D4iziSjHi4jxG8r4pta7z       Santiago De Chile       Los Bunkers
# 1  19CmuECYssqkPWANF4nLWM       Para No Verte Más  La Mosca Tse-Tse
# 2  2LsbizbOeNa4x6qsi2jAMb                La flaca    Jarabe De Palo
# 3  6hBfF54vgIAdtb5kbbvt75  Nada Nuevo Bajo El Sol       Los Bunkers
# 4  1qgtSWA2GbpAXfyC51M1ph                  Por Ti               4x3
#
#                genre  danceability  energy  loudness  speechiness  \
# 0       chilean rock         0.558   0.801    -5.796       0.0489
# 1  latin alternative         0.658   0.815    -6.834       0.1050
# 2  latin alternative         0.871   0.481    -9.068       0.0383
# 3       chilean rock         0.483   0.891    -4.813       0.0304
# 4    latin viral rap         0.761   0.535    -7.665       0.0600
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0      0.000126          0.000050    0.1760    0.542  120.090               4
# 1      0.016800          0.000000    0.3410    0.837   99.276               4
# 2      0.520000          0.000055    0.0809    0.664  103.063               4
# 3      0.069300          0.001220    0.0826    0.820  136.703               4
# 4      0.882000          0.000000    0.1830    0.899   90.965               4
#
#    key  mode
# 0    2     0
# 1    0     1
# 2    7     1
# 3    6     0
# 4    8     1

# %%
#guardar en un archivo CSV
df.to_csv('spotify_likes.csv', index=False)
